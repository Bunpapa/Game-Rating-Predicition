# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("C:\\Users\\Soumya\\Downloads\\games.csv (2)\\games.csv")

# %%
data
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# 0      white           15+2       bourgris          1500                a-00
# 1      black           5+10           a-00          1322           skinnerua
# 2      white           5+10         ischia          1496                a-00
# 3      white           20+0  daniamurashov          1439        adivanov2009
# 4      white           30+3      nik221107          1523        adivanov2009
# ...      ...            ...            ...           ...                 ...
# 20053  white          10+10        belcolt          1691            jamboger
# 20054  black           10+0       jamboger          1233  farrukhasomiddinov
# 20055  white           10+0       jamboger          1219        schaaksmurf3
# 20056  white           10+0   marcodisogno          1360            jamboger
# 20057  black           10+0       jamboger          1235               ffbob
#
#        black_rating                                              moves  \
# 0              1191  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...
# 1              1261  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...
# 2              1500  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...
# 3              1454  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...
# 4              1469  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...
# ...             ...                                                ...
# 20053          1220  d4 f5 e3 e6 Nf3 Nf6 Nc3 b6 Be2 Bb7 O-O Be7 Ne5...
# 20054          1196  d4 d6 Bf4 e5 Bg3 Nf6 e3 exd4 exd4 d5 c3 Bd6 Bd...
# 20055          1286  d4 d5 Bf4 Nc6 e3 Nf6 c3 e6 Nf3 Be7 Bd3 O-O Nbd...
# 20056          1227  e4 d6 d4 Nf6 e5 dxe5 dxe5 Qxd1+ Kxd1 Nd5 c4 Nb...
# 20057          1339  d4 d5 Bf4 Na6 e3 e6 c3 Nf6 Nf3 Bd7 Nbd2 b5 Bd3...
#
#       opening_eco                            opening_name  opening_ply
# 0             D10        Slav Defense: Exchange Variation            5
# 1             B00  Nimzowitsch Defense: Kennedy Variation            4
# 2             C20   King's Pawn Game: Leonardis Variation            3
# 3             D02  Queen's Pawn Game: Zukertort Variation            3
# 4             C41                        Philidor Defense            5
# ...           ...                                     ...          ...
# 20053         A80                           Dutch Defense            2
# 20054         A41                            Queen's Pawn            2
# 20055         D00         Queen's Pawn Game: Mason Attack            3
# 20056         B07                            Pirc Defense            4
# 20057         D00         Queen's Pawn Game: Mason Attack            3
#
# [20058 rows x 16 columns]

# %%
data.describe()
# Out:
#          created_at  last_move_at         turns  white_rating  black_rating  \
# count  2.005800e+04  2.005800e+04  20058.000000  20058.000000  20058.000000
# mean   1.483617e+12  1.483618e+12     60.465999   1596.631868   1588.831987
# std    2.850151e+10  2.850140e+10     33.570585    291.253376    291.036126
# min    1.376772e+12  1.376772e+12      1.000000    784.000000    789.000000
# 25%    1.477548e+12  1.477548e+12     37.000000   1398.000000   1391.000000
# 50%    1.496010e+12  1.496010e+12     55.000000   1567.000000   1562.000000
# 75%    1.503170e+12  1.503170e+12     79.000000   1793.000000   1784.000000
# max    1.504493e+12  1.504494e+12    349.000000   2700.000000   2723.000000
#
#         opening_ply
# count  20058.000000
# mean       4.816981
# std        2.797152
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       28.000000

# %%
data.white_id.value_counts()
data.black_id.value_counts()
# Out:
# black_id
# taranga               82
# vladimir-kramnik-1    60
# a_p_t_e_m_u_u         47
# docboss               44
# king5891              44
#                       ..
# cm0911                 1
# harland                1
# wansilence             1
# grooveman              1
# ffbob                  1
# Name: count, Length: 9331, dtype: int64

# %%
data.dtypes
# Out:
# id                 object
# rated                bool
# created_at        float64
# last_move_at      float64
# turns               int64
# victory_status     object
# winner             object
# increment_code     object
# white_id           object
# white_rating        int64
# black_id           object
# black_rating        int64
# moves              object
# opening_eco        object
# opening_name       object
# opening_ply         int64
# dtype: object

# %%
data.shape
# Out:
# (20058, 16)

# %%
data.winner.replace({"draw":"black"},inplace=True)

# %%
data.winner .value_counts()
# Out:
# winner
# black    10057
# white    10001
# Name: count, dtype: int64

# %% [markdown]
# # missing values

# %%
data.isnull().sum()
# Out:
# id                0
# rated             0
# created_at        0
# last_move_at      0
# turns             0
# victory_status    0
# winner            0
# increment_code    0
# white_id          0
# white_rating      0
# black_id          0
# black_rating      0
# moves             0
# opening_eco       0
# opening_name      0
# opening_ply       0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20053    False
# 20054    False
# 20055    False
# 20056    False
# 20057    False
# Length: 20058, dtype: bool

# %%
data.head()
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
#                                                moves opening_eco  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 2  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
# 3  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...         D02
# 4  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...         C41
#
#                              opening_name  opening_ply
# 0        Slav Defense: Exchange Variation            5
# 1  Nimzowitsch Defense: Kennedy Variation            4
# 2   King's Pawn Game: Leonardis Variation            3
# 3  Queen's Pawn Game: Zukertort Variation            3
# 4                        Philidor Defense            5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20058 non-null  object
#  1   rated           20058 non-null  bool
#  2   created_at      20058 non-null  float64
#  3   last_move_at    20058 non-null  float64
#  4   turns           20058 non-null  int64
#  5   victory_status  20058 non-null  object
#  6   winner          20058 non-null  object
#  7   increment_code  20058 non-null  object
#  8   white_id        20058 non-null  object
#  9   white_rating    20058 non-null  int64
#  10  black_id        20058 non-null  object
#  11  black_rating    20058 non-null  int64
#  12  moves           20058 non-null  object
#  13  opening_eco     20058 non-null  object
#  14  opening_name    20058 non-null  object
#  15  opening_ply     20058 non-null  int64
# dtypes: bool(1), float64(2), int64(4), object(9)
# memory usage: 2.3+ MB

# %%
data.columns
# Out:
# Index(['id', 'rated', 'created_at', 'last_move_at', 'turns', 'victory_status',
#        'winner', 'increment_code', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_eco', 'opening_name', 'opening_ply'],
#       dtype='object')

# %% [markdown]
# # data type conversion

# %%
# label Encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.rated=le.fit_transform(data.rated)

# %%
data.white_id=le.fit_transform(data.white_id)

# %%
data.winner=le.fit_transform(data.winner)

# %%
data.increment_code=le.fit_transform(data.increment_code)

# %%
data.black_id=le.fit_transform(data.black_id)

# %%
data.opening_eco=le.fit_transform(data.opening_eco)

# %%
data.moves=le.fit_transform(data.moves)

# %%
data.opening_name=le.fit_transform(data.opening_name)

# %%
data.victory_status=le.fit_transform(data.victory_status)

# %%
data.dtypes
# Out:
# id                 object
# rated               int64
# created_at        float64
# last_move_at      float64
# turns               int64
# victory_status      int32
# winner              int32
# increment_code      int32
# white_id            int32
# white_rating        int64
# black_id            int32
# black_rating        int64
# moves               int32
# opening_eco         int32
# opening_name        int32
# opening_ply         int64
# dtype: object

# %%
data=data.drop(["id"],axis=1)

# %% [markdown]
# # model building

# %%
winner=data["winner"]

# %%
data=data.drop(["winner"],axis=1)

# %%
data["winner"]=winner

# %%
data.head(1)
# Out:
#    rated    created_at  last_move_at  turns  victory_status  increment_code  \
# 0      0  1.504210e+12  1.504210e+12     13               2             110
#
#    white_id  white_rating  black_id  black_rating  moves  opening_eco  \
# 0      1287          1500        11          1191   4524          248
#
#    opening_name  opening_ply  winner
# 0          1387            5       1

# %%
data.shape
# Out:
# (20058, 15)

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x.head(1)
#y.head()
# Out:
#    rated    created_at  last_move_at  turns  victory_status  increment_code  \
# 0      0  1.504210e+12  1.504210e+12     13               2             110
#
#    white_id  white_rating  black_id  black_rating  moves  opening_eco  \
# 0      1287          1500        11          1191   4524          248
#
#    opening_name  opening_ply
# 0          1387            5

# %%
data.winner.value_counts()
# Out:
# winner
# 0    10057
# 1    10001
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_tr,x_te,y_tr,y_te=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
x_tr.shape,x_te.shape,y_tr.shape,y_te.shape
# Out:
# ((16046, 14), (4012, 14), (16046,), (4012,))

# %%
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
lg.fit(x_tr,y_tr)
# Out:
# LogisticRegression()

# %%
lg_p=lg.predict(x_te)
lg_p
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pred_prob=lg.predict_proba(x_te)
pred_prob
# Out:
# array([[0.50093643, 0.49906357],
#        [0.5009677 , 0.4990323 ],
#        [0.50096264, 0.49903736],
#        ...,
#        [0.5009124 , 0.4990876 ],
#        [0.50100955, 0.49899045],
#        [0.50091648, 0.49908352]])

# %%
from sklearn.metrics import confusion_matrix

# %%
lg_m=confusion_matrix(lg_p,y_te)
lg_m
# Out:
# array([[2023, 1989],
#        [   0,    0]], dtype=int64)

# %%
lg_acc=lg_m.diagonal().sum()/lg_m.sum()*100
lg_acc
# Out:
# 50.42372881355932

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(lg_p,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67      4012
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.50      4012
#    macro avg       0.50      0.25      0.34      4012
# weighted avg       1.00      0.50      0.67      4012

# %%
data.winner.value_counts()
# Out:
# winner
# 0    10057
# 1    10001
# Name: count, dtype: int64

# %%
#AUC-ROC Curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
df=pd.DataFrame(pred_prob)
df
# Out:
#              0         1
# 0     0.500936  0.499064
# 1     0.500968  0.499032
# 2     0.500963  0.499037
# 3     0.500930  0.499070
# 4     0.500936  0.499064
# ...        ...       ...
# 4007  0.500926  0.499074
# 4008  0.500898  0.499102
# 4009  0.500912  0.499088
# 4010  0.501010  0.498990
# 4011  0.500916  0.499084
#
# [4012 rows x 2 columns]

# %%
fpr,tpr,thrshold=roc_curve(y_te,df.iloc[:,1])

# %%
fpr
# Out:
# array([0.00000000e+00, 4.94315373e-04, 4.94315373e-04, ...,
#        9.98517054e-01, 9.98517054e-01, 1.00000000e+00])

# %%
tpr
# Out:
# array([0.00000000e+00, 0.00000000e+00, 5.02765209e-04, ...,
#        9.99497235e-01, 1.00000000e+00, 1.00000000e+00])

# %%
plt.plot(fpr,tpr)

# %%
#PRC
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %%
precision,recall,thershold=precision_recall_curve(y_te,df.iloc[:,1])

# %%
precision
# Out:
# array([0.49576271, 0.49588631, 0.49600998, ..., 0.5       , 0.        ,
#        1.        ])

# %%
recall
# Out:
# array([1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#        5.02765209e-04, 0.00000000e+00, 0.00000000e+00])

# %%
plt.plot(recall,precision,label="PRC-Curve")
plt.xlabel("recall")
plt.ylabel("precision")
plt.legend(loc="upper left")
plt.title("Precision-Recall")
# Out:
# Text(0.5, 1.0, 'Precision-Recall')

# %%
#tpr=tp/(tp+fn)
tpr=2023/(2023+0)
tpr
# Out:
# 1.0

# %%
#fpr=fp/(fp+tn)
fpr=1989/(1989+0)
fpr
# Out:
# 1.0

# %%
#precision=tp/(tp+fp)
precesion=2023/(2023+1989)
precesion
# Out:
# 0.5042372881355932

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score=(2*(precesion*tpr))/(precesion+tpr)
f1score
# Out:
# 0.6704225352112676

# %% [markdown]
# # decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x_tr,y_tr)
# Out:
# DecisionTreeClassifier()

# %%
dt_p=dt.predict(x_te)
dt_p
# Out:
# array([0, 1, 0, ..., 1, 1, 1])

# %%
dt_m=confusion_matrix(dt_p,y_te)
dt_m
# Out:
# array([[1274,  747],
#        [ 749, 1242]], dtype=int64)

# %%
dt_acc=dt_m.diagonal().sum()/dt_m.sum()*100
dt_acc
# Out:
# 62.71186440677966

# %%
dt.feature_importances_
# Out:
# array([0.00751963, 0.04726217, 0.04544224, 0.09194276, 0.06475933,
#        0.04432882, 0.08012195, 0.15621072, 0.08674525, 0.14396951,
#        0.08367126, 0.04709085, 0.06853829, 0.03239723])

# %%
dt_df=pd.DataFrame({"Importance":list(dt.feature_importances_),"Columns":list(x)})
dt_df
# Out:
#     Importance         Columns
# 0     0.007520           rated
# 1     0.047262      created_at
# 2     0.045442    last_move_at
# 3     0.091943           turns
# 4     0.064759  victory_status
# 5     0.044329  increment_code
# 6     0.080122        white_id
# 7     0.156211    white_rating
# 8     0.086745        black_id
# 9     0.143970    black_rating
# 10    0.083671           moves
# 11    0.047091     opening_eco
# 12    0.068538    opening_name
# 13    0.032397     opening_ply

# %%
print(classification_report(dt_p,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63      2021
#            1       0.62      0.62      0.62      1991
#
#     accuracy                           0.63      4012
#    macro avg       0.63      0.63      0.63      4012
# weighted avg       0.63      0.63      0.63      4012

# %%
#tpr=tp/(tp+fn)
tpr1=1267/(1267+756)
tpr1
# Out:
# 0.6262975778546713

# %%
#fpr=fp/(fp+tn)
fpr1=745/(745+1244)
fpr1
# Out:
# 0.3745600804424334

# %%
#precision=tp/(tp+fp)
precesion1=1267/(1267+745)
precesion1
# Out:
# 0.6297216699801192

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score1=(2*(precesion1*tpr1))/(precesion1+tpr1)
f1score1
# Out:
# 0.6280049566294919

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x_tr,y_tr)
# Out:
# RandomForestClassifier()

# %%
rf_p=rf.predict(x_te)
rf_p
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
rf_m=confusion_matrix(rf_p,y_te)
rf_m
# Out:
# array([[1399,  596],
#        [ 624, 1393]], dtype=int64)

# %%
rf_acc=rf_m.diagonal().sum()/rf_m.sum()*100
rf_acc
# Out:
# 69.59122632103688

# %%
print(classification_report(rf_p,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.70      0.70      1995
#            1       0.70      0.69      0.70      2017
#
#     accuracy                           0.70      4012
#    macro avg       0.70      0.70      0.70      4012
# weighted avg       0.70      0.70      0.70      4012

# %%
#tpr=tp/(tp+fn)
tpr2=1390/(1390+633)
tpr2
# Out:
# 0.6870983687592684

# %%
#fpr=fp/(fp+tn)
fpr2=585/(585+1404)
fpr2
# Out:
# 0.29411764705882354

# %%
#precision=tp/(tp+fp)
precesion2=1390/(1390+585)
precesion2
# Out:
# 0.7037974683544304

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score2=(2*(precesion2*tpr2))/(precesion2+tpr2)
f1score2
# Out:
# 0.6953476738369185

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=25)

# %%
knn.fit(x_tr,y_tr)
# Out:
# KNeighborsClassifier(n_neighbors=25)

# %%
knn_p=knn.predict(x_te)

# %%
knn_m=confusion_matrix(knn_p,y_te)
knn_m
# Out:
# array([[ 998,  969],
#        [1025, 1020]], dtype=int64)

# %%
knn_acc=knn_m.diagonal().sum()/knn_m.sum()*100
knn_acc
# Out:
# 50.299102691924226

# %%
print(classification_report(knn_p,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.51      0.50      1967
#            1       0.51      0.50      0.51      2045
#
#     accuracy                           0.50      4012
#    macro avg       0.50      0.50      0.50      4012
# weighted avg       0.50      0.50      0.50      4012

# %%
lst=list()

# %%
for i in range(1,30):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_tr,y_tr)
    knp=knn.predict(x_te)
    c=confusion_matrix(knp,y_te)
    acc=c.diagonal().sum()/c.sum()*100
    lst.append(acc)

# %%
p=plt.plot(lst)

# %%
#tpr=tp/(tp+fn)
tpr3=998/(998+1025)
tpr3
# Out:
# 0.49332674246169056

# %%
#fpr=fp/(fp+tn)
fpr3=969/(969+1020)
fpr3
# Out:
# 0.48717948717948717

# %%
#precision=tp/(tp+fp)
precesion3=998/(998+969)
precesion3
# Out:
# 0.507371631926792

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score3=(2*(precesion3*tpr3))/(precesion3+tpr3)
f1score3
# Out:
# 0.500250626566416

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(x_tr,y_tr)
# Out:
# SVC()

# %%
svc_p=svc.predict(x_te)

# %%
svc_m=confusion_matrix(svc_p,y_te)
svc_m
# Out:
# array([[1837, 1829],
#        [ 186,  160]], dtype=int64)

# %%
svc_acc=svc_m.diagonal().sum()/svc_m.sum()*100

# %%
svc_acc
# Out:
# 49.77567298105683

# %%
print(classification_report(svc_p,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.50      0.65      3666
#            1       0.08      0.46      0.14       346
#
#     accuracy                           0.50      4012
#    macro avg       0.49      0.48      0.39      4012
# weighted avg       0.84      0.50      0.60      4012

# %%
#tpr=tp/(tp+fn)
tpr4=1837/(1837+186)
tpr4
# Out:
# 0.9080573405832921

# %%
#fpr=fp/(fp+tn)
fpr4=1829/(1829+160)
fpr4
# Out:
# 0.9195575666163901

# %%
#precision=tp/(tp+fp)
precesion4=1837/(1837+1829)
precesion4
# Out:
# 0.5010911074740863

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score4=(2*(precesion4*tpr4))/(precesion4+tpr4)
f1score4
# Out:
# 0.6458076990683775

# %% [markdown]
# # ADDABOSST

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
adbo=AdaBoostClassifier(DecisionTreeClassifier(),n_estimators=5)

# %%
adbo.fit(x_tr,y_tr)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=5)

# %%
adbo_p=adbo.predict(x_te)

# %%
adboo_m=confusion_matrix(adbo_p,y_te)
adboo_m
# Out:
# array([[1277,  725],
#        [ 746, 1264]], dtype=int64)

# %%
adbo_acc=adboo_m.diagonal().sum()/adboo_m.sum()*100
adbo_acc
# Out:
# 63.33499501495513

# %%
print(classification_report(adbo_p,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.63      2002
#            1       0.64      0.63      0.63      2010
#
#     accuracy                           0.63      4012
#    macro avg       0.63      0.63      0.63      4012
# weighted avg       0.63      0.63      0.63      4012

# %%
#tpr=tp/(tp+fn)
tpr5=1268/(1268+755)
tpr5
# Out:
# 0.6267918932278794

# %%
#fpr=fp/(fp+tn)
fpr5=753/(753+1236)
fpr5
# Out:
# 0.37858220211161386

# %%
#precision=tp/(tp+fp)
precesion5=1268/(1268+753)
precesion5
# Out:
# 0.6274121721919842

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score5=(2*(precesion5*tpr5))/(precesion5+tpr5)
f1score5
# Out:
# 0.6271018793273986

# %% [markdown]
# # XG BOOST

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()

# %%
xgb.fit(x_tr,y_tr)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb_p=xgb.predict(x_te)

# %%
xgb_m=confusion_matrix(xgb_p,y_te)
xgb_m
# Out:
# array([[1771,  262],
#        [ 252, 1727]], dtype=int64)

# %%
xgb_acc=xgb_m.diagonal().sum()/xgb_m.sum()*100
xgb_acc
# Out:
# 87.18843469591226

# %%
print(classification_report(xgb_p,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      2033
#            1       0.87      0.87      0.87      1979
#
#     accuracy                           0.87      4012
#    macro avg       0.87      0.87      0.87      4012
# weighted avg       0.87      0.87      0.87      4012

# %%
#tpr=tp/(tp+fn)
tpr6=1771/(1771+252)
tpr6
# Out:
# 0.8754325259515571

# %%
#fpr=fp/(fp+tn)
fpr6=262/(262+1727)
fpr6
# Out:
# 0.13172448466566114

# %%
#precision=tp/(tp+fp)
precesion6=1771/(1771+262)
precesion6
# Out:
# 0.8711264141662568

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score6=(2*(precesion6*tpr6))/(precesion6+tpr6)
f1score6
# Out:
# 0.8732741617357003

# %%
#DF-1`
l1=["log","dt","rf","svc","knn","adaboost","xgboost"]
l2=[lg_acc,dt_acc,rf_acc,svc_acc,knn_acc,adbo_acc,xgb_acc]
l3=[fpr,fpr1,fpr2,fpr3,fpr4,fpr5,fpr6]
l4=[tpr,tpr1,tpr2,tpr3,tpr4,tpr5,tpr6]
l5=[f1score,f1score1,f1score3,f1score3,f1score4,f1score5,f1score6]

# %%
final=pd.DataFrame({"Model_Name":l1,"accuracy":l2,"fpr":l3,"tpr":l4,"f1score":l5})
final
# Out:
#   Model_Name   accuracy       fpr       tpr   f1score
# 0        log  50.423729  1.000000  1.000000  0.670423
# 1         dt  62.711864  0.374560  0.626298  0.628005
# 2         rf  69.591226  0.294118  0.687098  0.500251
# 3        svc  49.775673  0.487179  0.493327  0.500251
# 4        knn  50.299103  0.919558  0.908057  0.645808
# 5   adaboost  63.334995  0.378582  0.626792  0.627102
# 6    xgboost  87.188435  0.131724  0.875433  0.873274

# %% [markdown]
# # outliers

# %%
import pandas as pd

# Load the dataset into a variable named 'data'
data = pd.read_csv("C:\\Users\\Soumya\\Downloads\\games.csv (2)\\games.csv")
data['winner'] = data['winner'].replace('draw', 'black')

data["winner"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='winner'>

# %%
data.turns.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.turns.value_counts()
#
# NameError: name 'data' is not defined

# %%
data.white_rating.value_counts()
# Out:
# white_rating
# 1500    812
# 1480     51
# 1400     48
# 1536     46
# 1708     45
#        ...
# 788       1
# 1022      1
# 801       1
# 807       1
# 880       1
# Name: count, Length: 1516, dtype: int64

# %%
data.black_rating.value_counts()
# Out:
# black_rating
# 1500    797
# 1400     69
# 1501     53
# 1810     49
# 1562     45
#        ...
# 2293      1
# 949       1
# 932       1
# 1007      1
# 860       1
# Name: count, Length: 1521, dtype: int64

# %%
data.opening_ply.value_counts()
# Out:
# opening_ply
# 3     3490
# 4     3308
# 2     2935
# 5     2730
# 6     2020
# 7     1344
# 8     1116
# 1     1097
# 9      687
# 10     432
# 11     425
# 12     142
# 13     127
# 14      57
# 15      43
# 17      37
# 16      31
# 18      12
# 19      11
# 20       8
# 28       4
# 22       1
# 24       1
# Name: count, dtype: int64

# %%
sns.boxplot(data["turns"])
# Out:
# <Axes: >

# %%
sns.distplot(data["turns"])
# Out:
# <Axes: xlabel='turns', ylabel='Density'>

# %%
IQR=data.turns.quantile(0.75)-data.turns.quantile(0.25)
IQR
# Out:
# 42.0

# %%
lb=data["turns"].quantile(0.75)-IQR*3
ub=data["turns"].quantile(0.25)+IQR*3
lb,ub
# Out:
# (-47.0, 163.0)

# %%
data.loc[data["turns"]>163.0,"turns"]=163.0

# %%
sns.boxplot(data["white_rating"])
# Out:
# <Axes: >

# %%
sns.distplot(data["white_rating"])
# Out:
# <Axes: xlabel='white_rating', ylabel='Density'>

# %%
up2=data["white_rating"].mean()+3*data["white_rating"].std()
lb2=data["white_rating"].mean()-3*data["white_rating"].std()
print(up2,lb2)
# Out:
# 2470.3919947950644 722.8717403729481

# %%
data.loc[data["white_rating"]<2470.391,"white_rating"]=2470.391
data.loc[data["white_rating"]>722.8717,"white_rating"]=722.8717

# %%
sns.boxplot(data["black_rating"])
# Out:
# <Axes: >

# %%
sns.distplot(data["black_rating"])
# Out:
# <Axes: xlabel='black_rating', ylabel='Density'>

# %%
up1=data["black_rating"].mean()+3*data["black_rating"].std()
lb1=data["black_rating"].mean()-3*data["black_rating"].std()
print(up1,lb1)
# Out:
# 2461.9403651180237 715.7236093560018

# %%
data.loc[data["white_rating"]<2461.9403651180237,"white_rating"]=2461.9403651180237
data.loc[data["white_rating"]>715.7236093560018,"white_rating"]=715.7236093560018

# %% [markdown]
# # skewness

# %%
data.skew()
# Out:
# rated            -1.543074
# created_at       -1.782559
# last_move_at     -1.782554
# turns             0.737803
# victory_status   -0.562868
# increment_code    0.813804
# white_id          0.029349
# white_rating      0.000000
# black_id          0.016729
# black_rating      0.258510
# moves            -0.003726
# opening_eco       0.012413
# opening_name     -0.086998
# opening_ply       1.334557
# winner            0.005584
# dtype: float64

# %% [markdown]
# # visulization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
chess_data = pd.read_csv("C:\\Users\\Soumya\\Downloads\\games.csv (2)\\games.csv")

# Combine draws with the 'black' category
chess_data['winner'] = chess_data['winner'].replace('draw', 'black')

# Filter the data for 'white' and 'black' winners only
filtered_data = chess_data[chess_data['winner'].isin(['white', 'black'])]

# Count the occurrences of each unique value in the filtered data
winner_counts = filtered_data['winner'].value_counts()

# Plot the bar graph
plt.figure(figsize=(8, 6))
winner_counts.plot(kind='bar', color=['red', 'blue'])
plt.title('Winner Distribution in Chess Matches')
plt.xlabel('Winner')
plt.ylabel('Frequency')
plt.xticks(rotation=0)  # Reset x-axis labels rotation
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
chess_data = pd.read_csv("C:\\Users\\Soumya\\Downloads\\games.csv (2)\\games.csv")

# Count the occurrences of each unique value in the filtered data
winner_counts = filtered_data['winner'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(winner_counts, labels=winner_counts.index, autopct='%1.1f%%', colors=['red', 'blue'])
plt.title('Winner Distribution in Chess Matches')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %% [markdown]
# # model building

# %%
xo=class_1.iloc[:,:-1]
yo=class_1.iloc[:,-1]

# %%
yo.shape,xo.shape
# Out:
# ((20114,), (20114, 14))

# %%
x1_tr,x1_te,y1_tr,y1_te=train_test_split(xo,yo,test_size=0.2,random_state=100)

# %%
x1_tr.shape,x1_te.shape,y1_tr.shape,y1_te.shape
# Out:
# ((16091, 14), (4023, 14), (16091,), (4023,))

# %%
#log
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
lg.fit(x1_tr,y1_tr)
# Out:
# LogisticRegression()

# %%
lg_p1=lg.predict(x1_te)
lg_p1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
lg_m1=confusion_matrix(lg_p1,y1_te)
lg_m1
# Out:
# array([[1991, 2032],
#        [   0,    0]], dtype=int64)

# %%
lg_acc1=lg_m1.diagonal().sum()/lg_m1.sum()*100
lg_acc1
# Out:
# 49.49043002734278

# %%
print(classification_report(lg_p1,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.49      0.66      4023
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.49      4023
#    macro avg       0.50      0.25      0.33      4023
# weighted avg       1.00      0.49      0.66      4023

# %%
#tpr=tp/(tp+fn)
tpr7=1991/(1991+0)
tpr7
# Out:
# 1.0

# %%
#fpr=fp/(fp+tn)
fpr7=2032 /(2032+0)
fpr7
# Out:
# 1.0

# %%
#precision=tp/(tp+fp)
precesion7=1991/(1991+2032)
precesion7
# Out:
# 0.4949043002734278

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score7=(2*(precesion7*tpr7))/(precesion7+tpr7)
f1score7
# Out:
# 0.6621217159960092

# %%
#dt
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x1_tr,y1_tr)
# Out:
# DecisionTreeClassifier()

# %%
dt_p1=dt.predict(x1_te)
dt_p1
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
dt_m1=confusion_matrix(dt_p1,y1_te)
dt_m1
# Out:
# array([[1400,  431],
#        [ 591, 1601]], dtype=int64)

# %%
dt_acc1=dt_m1.diagonal().sum()/dt_m1.sum()*100
dt_acc1
# Out:
# 74.59607258264977

# %%
print(classification_report(dt_p1,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.76      0.73      1831
#            1       0.79      0.73      0.76      2192
#
#     accuracy                           0.75      4023
#    macro avg       0.75      0.75      0.75      4023
# weighted avg       0.75      0.75      0.75      4023

# %%
#tpr=tp/(tp+fn)
tpr8=1381/(1381+610)
tpr8
# Out:
# 0.6936212958312405

# %%
#fpr=fp/(fp+tn)
fpr8=404/(404+1628)
fpr8
# Out:
# 0.19881889763779528

# %%
#precision=tp/(tp+fp)
precesion8=1381/(1381+404)
precesion8
# Out:
# 0.7736694677871149

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score8=(2*(precesion8*tpr8))/(precesion8+tpr8)
f1score8
# Out:
# 0.7314618644067796

# %%
#rf
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x1_tr,y1_tr)
# Out:
# RandomForestClassifier()

# %%
rf_pre1=rf.predict(x1_te)
rf_pre1
# Out:
# array([1, 1, 0, ..., 0, 1, 1])

# %%
rf_mat1=confusion_matrix(rf_pre1,y1_te)
rf_mat1
# Out:
# array([[1581,  405],
#        [ 410, 1627]], dtype=int64)

# %%
rf_acc1=rf_mat1.diagonal().sum()/rf_mat1.sum()*100
rf_acc1
# Out:
# 79.74148645289586

# %%
print(classification_report (rf_pre1,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80      1986
#            1       0.80      0.80      0.80      2037
#
#     accuracy                           0.80      4023
#    macro avg       0.80      0.80      0.80      4023
# weighted avg       0.80      0.80      0.80      4023

# %%
#tpr=tp/(tp+fn)
tpr9=1585/(1585+406)
tpr9
# Out:
# 0.796082370668006

# %%
#fpr=fp/(fp+tn)
fpr9=395/(395+1637)
fpr9
# Out:
# 0.19438976377952755

# %%
#precision=tp/(tp+fp)
precesion9=1585/(1585+395)
precesion9
# Out:
# 0.8005050505050505

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score9=(2*(precesion9*tpr9))/(precesion9+tpr9)
f1score9
# Out:
# 0.7982875849911861

# %%
#svm
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(x1_tr,y1_tr)
# Out:
# SVC()

# %%
svc_p1=svc.predict(x1_te)

# %%
svc_m1=confusion_matrix(svc_p1,y1_te)
svc_m1
# Out:
# array([[1910, 1926],
#        [  81,  106]], dtype=int64)

# %%
svc_acc1=svc_m1.diagonal().sum()/svc_m1.sum()*100
svc_acc1
# Out:
# 50.11185682326622

# %%
print(classification_report(svc_p1,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.50      0.66      3836
#            1       0.05      0.57      0.10       187
#
#     accuracy                           0.50      4023
#    macro avg       0.51      0.53      0.38      4023
# weighted avg       0.92      0.50      0.63      4023

# %%
#tpr=tp/(tp+fn)
tpr10=1991/(1991+0)
tpr10
# Out:
# 1.0

# %%
#fpr=fp/(fp+tn)
fpr10=2032/(2032+0)
fpr10
# Out:
# 1.0

# %%
#precision=tp/(tp+fp)
precesion10=1991/(1991+2032)
precesion10
# Out:
# 0.4949043002734278

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score10=(2*(precesion10*tpr10))/(precesion10+tpr10)
f1score10
# Out:
# 0.6621217159960092

# %%
#knn
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=15)

# %%
knn.fit(x1_tr,y1_tr)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
knn_p1=knn.predict(x1_te)

# %%
knn_m1=confusion_matrix(knn_p1,y1_te)
knn_m1
# Out:
# array([[1009,  851],
#        [ 982, 1181]], dtype=int64)

# %%
knn_acc1=knn_m1.diagonal().sum()/knn_m1.sum()*100
knn_acc1
# Out:
# 54.43698732289336

# %%
print(classification_report(knn_p1,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.52      1860
#            1       0.58      0.55      0.56      2163
#
#     accuracy                           0.54      4023
#    macro avg       0.54      0.54      0.54      4023
# weighted avg       0.55      0.54      0.55      4023

# %%
#tpr=tp/(tp+fn)
tpr11=1035/(1035+956)
tpr11
# Out:
# 0.5198392767453541

# %%
#fpr=fp/(fp+tn)
fpr11=879/(879+1153)
fpr11
# Out:
# 0.4325787401574803

# %%
#precision=tp/(tp+fp)
precesion11=1035/(1035+879)
precesion11
# Out:
# 0.5407523510971787

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score11=(2*(precesion11*tpr11))/(precesion11+tpr11)
f1score11
# Out:
# 0.530089628681178

# %%
#AdaBoost
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
adbo=AdaBoostClassifier(DecisionTreeClassifier(),n_estimators=5)

# %%
adbo.fit(x1_tr,y1_tr)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=5)

# %%
adbo_p1=adbo.predict(x1_te)

# %%
adboo_m1=confusion_matrix(adbo_p1,y1_te)
adboo_m1
# Out:
# array([[1402,  409],
#        [ 589, 1623]], dtype=int64)

# %%
adbo_acc1=adboo_m1.diagonal().sum()/adboo_m1.sum()*100
adbo_acc1
# Out:
# 75.19264230673627

# %%
print(classification_report(adbo_p1,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.77      0.74      1811
#            1       0.80      0.73      0.76      2212
#
#     accuracy                           0.75      4023
#    macro avg       0.75      0.75      0.75      4023
# weighted avg       0.76      0.75      0.75      4023

# %%
#tpr=tp/(tp+fn)
tpr12=1391/(1391+600)
tpr12
# Out:
# 0.6986438975389252

# %%
#fpr=fp/(fp+tn)
fpr12=406/(406+1626)
fpr12
# Out:
# 0.19980314960629922

# %%
#precision=tp/(tp+fp)
precesion12=1391/(1391+406)
precesion12
# Out:
# 0.7740678909293267

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score12=(2*(precesion12*tpr12))/(precesion12+tpr12)
f1score12
# Out:
# 0.7344244984160507

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()

# %%
xgb.fit(x1_tr,y1_tr)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb_p1=xgb.predict(x1_te)

# %%
xgb_m1=confusion_matrix(xgb_p1,y1_te)
xgb_m1
# Out:
# array([[1787,  205],
#        [ 204, 1827]], dtype=int64)

# %%
xgb_acc1=xgb_m1.diagonal().sum()/xgb_m1.sum()*100
xgb_acc1
# Out:
# 89.83345761869252

# %%
print(classification_report(xgb_p1,y1_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      1992
#            1       0.90      0.90      0.90      2031
#
#     accuracy                           0.90      4023
#    macro avg       0.90      0.90      0.90      4023
# weighted avg       0.90      0.90      0.90      4023

# %%
#tpr=tp/(tp+fn)
tpr13=1764/(1764+227)
tpr13
# Out:
# 0.88598694123556

# %%
#fpr=fp/(fp+tn)
fpr13=159/(159+1873)
fpr13
# Out:
# 0.07824803149606299

# %%
#precision=tp/(tp+fp)
precesion13=1764/(1764+159)
precesion13
# Out:
# 0.9173166926677067

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score13=(2*(precesion13*tpr13))/(precesion13+tpr13)
f1score13
# Out:
# 0.9013796627491057

# %%
 #DF-2
l1=["log","dt","rf","svc","knn","adaboost","xgboost"]
l2=[lg_acc1,dt_acc1,rf_acc1,svc_acc1,knn_acc1,adbo_acc1,xgb_acc1]
l3=[fpr7,fpr8,fpr9,fpr10,fpr11,fpr12,fpr13]
l4=[tpr7,tpr8,tpr9,tpr10,tpr11,tpr12,tpr13]
l5=[f1score7,f1score8,f1score9,f1score10,f1score11,f1score12,f1score13]

# %%
final=pd.DataFrame({"Model_Name":l1,"accuracy":l2,"fpr":l3,"tpr":l4,"f1score":l5})
final
# Out:
#   Model_Name   accuracy       fpr       tpr   f1score
# 0        log  49.490430  1.000000  1.000000  0.662122
# 1         dt  74.596073  0.198819  0.693621  0.731462
# 2         rf  79.741486  0.194390  0.796082  0.798288
# 3        svc  50.111857  1.000000  1.000000  0.662122
# 4        knn  54.436987  0.432579  0.519839  0.530090
# 5   adaboost  75.192642  0.199803  0.698644  0.734424
# 6    xgboost  89.833458  0.078248  0.885987  0.901380

# %% [markdown]
# # feature selection

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
dataTree=DecisionTreeClassifier()

# %%
rfe=RFE(dataTree)

# %%
rfe.fit(data.iloc[:,:-1],data.iloc[:,-1])
# Out:
# RFE(estimator=DecisionTreeClassifier())

# %%
rfe.support_
# Out:
# array([False, False,  True,  True, False, False,  True, False,  True,
#         True,  True, False,  True, False])

# %%
rfe_df=pd.DataFrame({"Importances":list(rfe.support_),"Columns":list(data.iloc[:,:-1].columns)})
rfe_df
# Out:
#     Importances         Columns
# 0         False           rated
# 1         False      created_at
# 2          True    last_move_at
# 3          True           turns
# 4         False  victory_status
# 5         False  increment_code
# 6          True        white_id
# 7         False    white_rating
# 8          True        black_id
# 9          True    black_rating
# 10         True           moves
# 11        False     opening_eco
# 12         True    opening_name
# 13        False     opening_ply

# %%
sorted_df =rfe_df.sort_values(["Importances"],ascending=False)
sorted_df
# Out:
#     Importances         Columns
# 2          True    last_move_at
# 3          True           turns
# 6          True        white_id
# 8          True        black_id
# 9          True    black_rating
# 10         True           moves
# 12         True    opening_name
# 0         False           rated
# 1         False      created_at
# 4         False  victory_status
# 5         False  increment_code
# 7         False    white_rating
# 11        False     opening_eco
# 13        False     opening_ply

# %%
data.columns
# Out:
# Index(['rated', 'created_at', 'last_move_at', 'turns', 'victory_status',
#        'increment_code', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_eco', 'opening_name', 'opening_ply',
#        'winner'],
#       dtype='object')

# %%
data1=data.drop(["rated","created_at","increment_code","white_rating","opening_eco","opening_name","opening_ply"],axis=1)

# %%
data1.head(1)
# Out:
#    last_move_at  turns  victory_status  white_id  black_id  black_rating  \
# 0  1.504210e+12     13               2      1287        11          1191
#
#    moves  winner
# 0   4524       1

# %%
x2=data1.iloc[:,:-1]
y2=data1.iloc[:,-1]

# %%
x2.head(1)
# Out:
#    last_move_at  turns  victory_status  white_id  black_id  black_rating  \
# 0  1.504210e+12     13               2      1287        11          1191
#
#    moves
# 0   4524

# %%
y2.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: winner, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x2_tr,x2_te,y2_tr,y2_te=train_test_split(x2,y2,test_size=0.2,random_state=100)

# %%
x2_tr.shape,x2_te.shape,y2_tr.shape,y2_te.shape
# Out:
# ((16046, 7), (4012, 7), (16046,), (4012,))

# %%
#log
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
lg.fit(x2_tr,y2_tr)
# Out:
# LogisticRegression()

# %%
lg_p3=lg.predict(x2_te)
lg_p3
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
lg_m3=confusion_matrix(lg_p3,y2_te)
lg_m3
# Out:
# array([[2023, 1989],
#        [   0,    0]], dtype=int64)

# %%
lg_acc3=lg_m3.diagonal().sum()/lg_m3.sum()*100
lg_acc3
# Out:
# 50.42372881355932

# %%
print(classification_report(lg_p3,y2_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67      4012
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.50      4012
#    macro avg       0.50      0.25      0.34      4012
# weighted avg       1.00      0.50      0.67      4012

# %%
#tpr=tp/(tp+fn)
tpr14=2023/(2023+0)
tpr14
# Out:
# 1.0

# %%
#fpr=fp/(fp+tn)
fpr14=1989/(1989+0)
fpr14
# Out:
# 1.0

# %%
#precision=tp/(tp+fp)
precesion14=2023/(2023+1989)
precesion14
# Out:
# 0.5042372881355932

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score14=(2*(precesion14*tpr14))/(precesion6+tpr14)
f1score14
# Out:
# 0.5389665650786861

# %%
#dt
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x2_tr,y2_tr)
# Out:
# DecisionTreeClassifier()

# %%
dt_p3=dt.predict(x2_te)
dt_p3
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
dt_m3=confusion_matrix(dt_p3,y2_te)
dt_m3
# Out:
# array([[1393,  622],
#        [ 630, 1367]], dtype=int64)

# %%
dt_acc3=dt_m3.diagonal().sum()/dt_m3.sum()*100
dt_acc3
# Out:
# 68.79361914257228

# %%
print(classification_report(dt_p3,y2_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69      2015
#            1       0.69      0.68      0.69      1997
#
#     accuracy                           0.69      4012
#    macro avg       0.69      0.69      0.69      4012
# weighted avg       0.69      0.69      0.69      4012

# %%
#tpr=tp/(tp+fn)
tpr15=1391/(1391+632)
tpr15
# Out:
# 0.6875926841324765

# %%
#fpr=fp/(fp+tn)
fpr15=614/(614+1375)
fpr15
# Out:
# 0.30869783810960283

# %%
#precision=tp/(tp+fp)
precesion15=1391/(1391+614)
precesion15
# Out:
# 0.6937655860349127

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score15=(2*(precesion15*tpr15))/(precesion15+tpr15)
f1score15
# Out:
# 0.6906653426017875

# %%
#rf
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x2_tr,y2_tr)
# Out:
# RandomForestClassifier()

# %%
rf_pre3=rf.predict(x2_te)
rf_pre3
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
rf_mat3=confusion_matrix(rf_pre3,y2_te)
rf_mat3
# Out:
# array([[1306,  596],
#        [ 717, 1393]], dtype=int64)

# %%
rf_acc3=rf_mat3.diagonal().sum()/rf_mat3.sum()*100
rf_acc3
# Out:
# 67.27318045862413

# %%
print(classification_report (rf_pre3,y2_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.69      0.67      1902
#            1       0.70      0.66      0.68      2110
#
#     accuracy                           0.67      4012
#    macro avg       0.67      0.67      0.67      4012
# weighted avg       0.67      0.67      0.67      4012

# %%
#tpr=tp/(tp+fn)
tpr16=1280/(1280+743)
tpr16
# Out:
# 0.6327236777063767

# %%
#fpr=fp/(fp+tn)
fpr16=581/(581+1408)
fpr16
# Out:
# 0.2921065862242333

# %%
#precision=tp/(tp+fp)
precesion16=1280/(1208+581)
precesion16
# Out:
# 0.7154835103409726

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score16=(2*(precesion16*tpr16))/(precesion16+tpr16)
f1score16
# Out:
# 0.671563483735572

# %%
#svm
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(x2_tr,y2_tr)
# Out:
# SVC()

# %%
svc_p3=svc.predict(x2_te)

# %%
svc_m3=confusion_matrix(svc_p3,y2_te)
svc_m3
# Out:
# array([[1837, 1829],
#        [ 186,  160]], dtype=int64)

# %%
svc_acc3=svc_m3.diagonal().sum()/svc_m3.sum()*100
svc_acc3
# Out:
# 49.77567298105683

# %%
print(classification_report(svc_p3,y2_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.50      0.65      3666
#            1       0.08      0.46      0.14       346
#
#     accuracy                           0.50      4012
#    macro avg       0.49      0.48      0.39      4012
# weighted avg       0.84      0.50      0.60      4012

# %%
#tpr=tp/(tp+fn)
tpr18=1837/(1837+186)
tpr18
# Out:
# 0.9080573405832921

# %%
#fpr=fp/(fp+tn)
fpr18=1829/(1829+160)
fpr18
# Out:
# 0.9195575666163901

# %%
#precision=tp/(tp+fp)
precesion18=1837/(1837+1829)
precesion18
# Out:
# 0.5010911074740863

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score18=(2*(precesion18*tpr18))/(precesion18+tpr18)
f1score18
# Out:
# 0.6458076990683775

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=15)

# %%
knn.fit(x2_tr,y2_tr)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
knn_p3=knn.predict(x2_te)

# %%
knn_m3=confusion_matrix(knn_p3,y2_te)
knn_m3
# Out:
# array([[1019,  985],
#        [1004, 1004]], dtype=int64)

# %%
knn_acc3=knn_m3.diagonal().sum()/knn_m3.sum()*100
knn_acc3
# Out:
# 50.42372881355932

# %%
print(classification_report(knn_p3,y2_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.51      2004
#            1       0.50      0.50      0.50      2008
#
#     accuracy                           0.50      4012
#    macro avg       0.50      0.50      0.50      4012
# weighted avg       0.50      0.50      0.50      4012

# %%
#tpr=tp/(tp+fn)
tpr19=1019/(1019+1004)
tpr19
# Out:
# 0.5037073652990608

# %%
#fpr=fp/(fp+tn)
fpr19=985/(985+1004)
fpr19
# Out:
# 0.4952237305178482

# %%
#precision=tp/(tp+fp)
precesion19=1019/(1019+985)
precesion19
# Out:
# 0.5084830339321357

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score19=(2*(precesion19*tpr19))/(precesion19+tpr19)
f1score19
# Out:
# 0.5060839334492178

# %%
#adaboost
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
adbo=AdaBoostClassifier(DecisionTreeClassifier(),n_estimators=5)

# %%
adbo.fit(x2_tr,y2_tr)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=5)

# %%
adbo_p3=adbo.predict(x2_te)

# %%
adboo_m3=confusion_matrix(adbo_p3,y2_te)
adboo_m3
# Out:
# array([[1402,  614],
#        [ 621, 1375]], dtype=int64)

# %%
adbo_acc3=adboo_m3.diagonal().sum()/adboo_m3.sum()*100
adbo_acc3
# Out:
# 69.2173479561316

# %%
print(classification_report(adbo_p3,y2_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.70      0.69      2016
#            1       0.69      0.69      0.69      1996
#
#     accuracy                           0.69      4012
#    macro avg       0.69      0.69      0.69      4012
# weighted avg       0.69      0.69      0.69      4012

# %%
#tpr=tp/(tp+fn)
tpr20=1399/(1399+624)
tpr20
# Out:
# 0.6915472071181413

# %%
#fpr=fp/(fp+tn)
fpr20=621/(621+1368)
fpr20
# Out:
# 0.31221719457013575

# %%
#precision=tp/(tp+fp)
precesion20=1399/(1399+621)
precesion20
# Out:
# 0.6925742574257425

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score20=(2*(precesion20*tpr20))/(precesion20+tpr20)
f1score20
# Out:
# 0.6920603512243384

# %%
#xgboost
from xgboost import XGBClassifier
xgb=XGBClassifier()

# %%
xgb.fit(x2_tr,y2_tr)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb_p3=xgb.predict(x2_te)

# %%
xgb_m3=confusion_matrix(xgb_p3,y2_te)
xgb_m3
# Out:
# array([[1790,  227],
#        [ 233, 1762]], dtype=int64)

# %%
xgb_acc3=xgb_m3.diagonal().sum()/xgb_m3.sum()*100
xgb_acc3
# Out:
# 88.53439680957128

# %%
print(classification_report(xgb_p3,y2_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89      2017
#            1       0.89      0.88      0.88      1995
#
#     accuracy                           0.89      4012
#    macro avg       0.89      0.89      0.89      4012
# weighted avg       0.89      0.89      0.89      4012

# %%
#tpr=tp/(tp+fn)
tpr21=1790/(1790+233)
tpr21
# Out:
# 0.8848245180425112

# %%
#fpr=fp/(fp+tn)
fpr21=227/(227+1762)
fpr21
# Out:
# 0.11412770236299648

# %%
#precision=tp/(tp+fp)
precesion21=1790/(1790+227)
precesion21
# Out:
# 0.887456618740704

# %%
#f1score=2(precesion*recall)/(precision+recall)
f1score21=(2*(precesion21*tpr21))/(precesion21+tpr21)
f1score21
# Out:
# 0.8861386138613861

# %%
#DF-3
l1=["log","dt","rf","svc","knn","adaboost","xgboost"]
l2=[lg_acc3,dt_acc3,rf_acc3,svc_acc3,knn_acc3,adbo_acc3,xgb_acc3]
l3=[fpr14,fpr15,fpr16,fpr18,fpr19,fpr20,fpr21]
l4=[tpr14,tpr15,tpr16,tpr18,tpr19,tpr20,tpr21]
l5=[f1score14,f1score15,f1score16,f1score18,f1score19,f1score20,f1score21]

# %%
final=pd.DataFrame({"Model_Name":l1,"accuracy":l2,"fpr":l3,"tpr":l4,"f1score":l5})
final
# Out:
#   Model_Name   accuracy       fpr       tpr   f1score
# 0        log  50.423729  1.000000  1.000000  0.538967
# 1         dt  68.793619  0.308698  0.687593  0.690665
# 2         rf  67.273180  0.292107  0.632724  0.671563
# 3        svc  49.775673  0.919558  0.908057  0.645808
# 4        knn  50.423729  0.495224  0.503707  0.506084
# 5   adaboost  69.217348  0.312217  0.691547  0.692060
# 6    xgboost  88.534397  0.114128  0.884825  0.886139
